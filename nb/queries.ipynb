# %%
import flor

flor.dataframe("img_ocr")
# Out:
#    document document_value           projid              tstamp      filename  \
# 0         6  IMG_7385.jpeg  document_parser 2024-10-22 10:10:39  doc_demux.py
#
#                                              img_ocr
# 0  maddowmaddow V 2h\nlol\nmac_ryan 4h\nwant to k...

# %%
flor.dataframe("page_ocr")
# Out:
#     document                               document_value  page page_value  \
# 0          1  160-Marlon_Maynor_v_Jamal_Brunson_et_al.pdf     1          0
# 1          1  160-Marlon_Maynor_v_Jamal_Brunson_et_al.pdf     2          1
# 2          1  160-Marlon_Maynor_v_Jamal_Brunson_et_al.pdf     3          2
# 3          1  160-Marlon_Maynor_v_Jamal_Brunson_et_al.pdf     4          3
# 4          1  160-Marlon_Maynor_v_Jamal_Brunson_et_al.pdf     5          4
# ..       ...                                          ...   ...        ...
# 63         5                143-Sparrow_v_Creed_et_al.pdf    19         18
# 64         5                143-Sparrow_v_Creed_et_al.pdf    20         19
# 65         5                143-Sparrow_v_Creed_et_al.pdf    21         20
# 66         5                143-Sparrow_v_Creed_et_al.pdf    22         21
# 67         5                143-Sparrow_v_Creed_et_al.pdf    23         22
#
#              projid              tstamp      filename  \
# ...

# %%
flor.dataframe("img_ocr", "page_ocr")
# Out:
#     document                               document_value           projid  \
# 0          1  160-Marlon_Maynor_v_Jamal_Brunson_et_al.pdf  document_parser
# 1          1  160-Marlon_Maynor_v_Jamal_Brunson_et_al.pdf  document_parser
# 2          1  160-Marlon_Maynor_v_Jamal_Brunson_et_al.pdf  document_parser
# 3          1  160-Marlon_Maynor_v_Jamal_Brunson_et_al.pdf  document_parser
# 4          1  160-Marlon_Maynor_v_Jamal_Brunson_et_al.pdf  document_parser
# ..       ...                                          ...              ...
# 64         5                143-Sparrow_v_Creed_et_al.pdf  document_parser
# 65         5                143-Sparrow_v_Creed_et_al.pdf  document_parser
# 66         5                143-Sparrow_v_Creed_et_al.pdf  document_parser
# 67         5                143-Sparrow_v_Creed_et_al.pdf  document_parser
# 68         6                                IMG_7385.jpeg  document_parser
#
#                 tstamp      filename  page page_value  \
# ...
