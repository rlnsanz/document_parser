# %%
import flor
df = flor.dataframe("page_text")
df
# Out:
#     document     document_value  page page_value           projid  \
# 0          1  UntitledSlice.pdf     1          0  document_parser
# 1          1  UntitledSlice.pdf     2          1  document_parser
# 2          1  UntitledSlice.pdf     3          2  document_parser
# 3          1  UntitledSlice.pdf     4          3  document_parser
# 4          1  UntitledSlice.pdf     5          4  document_parser
# 5          1  UntitledSlice.pdf     6          5  document_parser
# 6          1  UntitledSlice.pdf     7          6  document_parser
# 7          1  UntitledSlice.pdf     8          7  document_parser
# 8          1  UntitledSlice.pdf     9          8  document_parser
# 9          1  UntitledSlice.pdf    10          9  document_parser
# 10         1  UntitledSlice.pdf    11         10  document_parser
# 11         1  UntitledSlice.pdf    12         11  document_parser
# 12         1  UntitledSlice.pdf    13         12  document_parser
# 13         1  UntitledSlice.pdf    14         13  document_parser
# 14         1  UntitledSlice.pdf    15         14  document_parser
# 15         1  UntitledSlice.pdf    16         15  document_parser
# 16         1  UntitledSlice.pdf    17         16  document_parser
# 17         1  UntitledSlice.pdf    18         17  document_parser
# 18         1  UntitledSlice.pdf    19         18  document_parser
# 19         1  UntitledSlice.pdf    20         19  document_parser
#
#                 tstamp      filename  \
# 0  2025-08-29 14:32:53  doc_demux.py
# 1  2025-08-29 14:32:53  doc_demux.py
# 2  2025-08-29 14:32:53  doc_demux.py
# 3  2025-08-29 14:32:53  doc_demux.py
# 4  2025-08-29 14:32:53  doc_demux.py
# 5  2025-08-29 14:32:53  doc_demux.py
# 6  2025-08-29 14:32:53  doc_demux.py
# 7  2025-08-29 14:32:53  doc_demux.py
# 8  2025-08-29 14:32:53  doc_demux.py
# 9  2025-08-29 14:32:53  doc_demux.py
# 10 2025-08-29 14:32:53  doc_demux.py
# 11 2025-08-29 14:32:53  doc_demux.py
# 12 2025-08-29 14:32:53  doc_demux.py
# 13 2025-08-29 14:32:53  doc_demux.py
# 14 2025-08-29 14:32:53  doc_demux.py
# 15 2025-08-29 14:32:53  doc_demux.py
# 16 2025-08-29 14:32:53  doc_demux.py
# 17 2025-08-29 14:32:53  doc_demux.py
# 18 2025-08-29 14:32:53  doc_demux.py
# 19 2025-08-29 14:32:53  doc_demux.py
#
#                                             page_text
# 0   The stunning document of intellectual\ntransfo...
# 1   G u a r a n t e e   C a r d   /   保 修 卡\nID No...
# 2   vin\nCHAPTER III.\nTHE AUTHOR'S PARENTAGE.\nAu...
# 3   CHAPTER IX.\nPERSONAL TREATMENT O F T H E AUTH...
# 4   x i l\nNo more Meal brought from the Mill-Meth...
# 5   x i v\nHymns with a Double Meaning,\nAuthor's ...
# 6   xvi\nBecomes a Public Lecturer,\nYouthful Enth...
# 7   G u a r a n t e e   C a r d  /   保 修 卡\nID No....
# 8   INTRODUCTION\nx X\nand a lasting contribution ...
# 9   I N T R O D U C T I O N\nxxii\nFewer still rec...
# 10  INTRODUCTION\nx x i v\nBondage and Freedom is ...
# 11  INTRODUCTION\nxxvi\nterritories and northerner...
# 12  INTRODUCTION\nxxvili\nfor example, in 1833, he...
# 13  INTRODUCTION\nX X X\nriages of many slaveholdi...
# 14  INTRODUCTION\nxxxii\nin my spirit" (98). From ...
# 15  INTRODUCTION\nxxxiv\nhe became an expert caulk...
# 16  INTRODUCTION\nXXXVI\non his particular slave p...
# 17  xxxvili\nINTRODUCTION\nqualiﬁed for this if I ...
# 18  INTRODUCTION\nelse's text, rather than letting...
# 19  INTRODUCTION\nxlii\ncommitted what the Garriso...

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from user_defined_functions import get_headings, get_page_numbers

# %%
df["f_headings"] = df["page_text"].map(get_headings)
df
# Out:
#     document     document_value  page page_value           projid  \
# 0          1  UntitledSlice.pdf     1          0  document_parser
# 1          1  UntitledSlice.pdf     2          1  document_parser
# 2          1  UntitledSlice.pdf     3          2  document_parser
# 3          1  UntitledSlice.pdf     4          3  document_parser
# 4          1  UntitledSlice.pdf     5          4  document_parser
# 5          1  UntitledSlice.pdf     6          5  document_parser
# 6          1  UntitledSlice.pdf     7          6  document_parser
# 7          1  UntitledSlice.pdf     8          7  document_parser
# 8          1  UntitledSlice.pdf     9          8  document_parser
# 9          1  UntitledSlice.pdf    10          9  document_parser
# 10         1  UntitledSlice.pdf    11         10  document_parser
# 11         1  UntitledSlice.pdf    12         11  document_parser
# 12         1  UntitledSlice.pdf    13         12  document_parser
# 13         1  UntitledSlice.pdf    14         13  document_parser
# 14         1  UntitledSlice.pdf    15         14  document_parser
# 15         1  UntitledSlice.pdf    16         15  document_parser
# 16         1  UntitledSlice.pdf    17         16  document_parser
# 17         1  UntitledSlice.pdf    18         17  document_parser
# 18         1  UntitledSlice.pdf    19         18  document_parser
# 19         1  UntitledSlice.pdf    20         19  document_parser
#
#                 tstamp      filename  \
# 0  2025-08-29 14:32:53  doc_demux.py
# 1  2025-08-29 14:32:53  doc_demux.py
# 2  2025-08-29 14:32:53  doc_demux.py
# 3  2025-08-29 14:32:53  doc_demux.py
# 4  2025-08-29 14:32:53  doc_demux.py
# 5  2025-08-29 14:32:53  doc_demux.py
# 6  2025-08-29 14:32:53  doc_demux.py
# 7  2025-08-29 14:32:53  doc_demux.py
# 8  2025-08-29 14:32:53  doc_demux.py
# 9  2025-08-29 14:32:53  doc_demux.py
# 10 2025-08-29 14:32:53  doc_demux.py
# 11 2025-08-29 14:32:53  doc_demux.py
# 12 2025-08-29 14:32:53  doc_demux.py
# 13 2025-08-29 14:32:53  doc_demux.py
# 14 2025-08-29 14:32:53  doc_demux.py
# 15 2025-08-29 14:32:53  doc_demux.py
# 16 2025-08-29 14:32:53  doc_demux.py
# 17 2025-08-29 14:32:53  doc_demux.py
# 18 2025-08-29 14:32:53  doc_demux.py
# 19 2025-08-29 14:32:53  doc_demux.py
#
#                                             page_text  \
# 0   The stunning document of intellectual\ntransfo...
# 1   G u a r a n t e e   C a r d   /   保 修 卡\nID No...
# 2   vin\nCHAPTER III.\nTHE AUTHOR'S PARENTAGE.\nAu...
# 3   CHAPTER IX.\nPERSONAL TREATMENT O F T H E AUTH...
# 4   x i l\nNo more Meal brought from the Mill-Meth...
# 5   x i v\nHymns with a Double Meaning,\nAuthor's ...
# 6   xvi\nBecomes a Public Lecturer,\nYouthful Enth...
# 7   G u a r a n t e e   C a r d  /   保 修 卡\nID No....
# 8   INTRODUCTION\nx X\nand a lasting contribution ...
# 9   I N T R O D U C T I O N\nxxii\nFewer still rec...
# 10  INTRODUCTION\nx x i v\nBondage and Freedom is ...
# 11  INTRODUCTION\nxxvi\nterritories and northerner...
# 12  INTRODUCTION\nxxvili\nfor example, in 1833, he...
# 13  INTRODUCTION\nX X X\nriages of many slaveholdi...
# 14  INTRODUCTION\nxxxii\nin my spirit" (98). From ...
# 15  INTRODUCTION\nxxxiv\nhe became an expert caulk...
# 16  INTRODUCTION\nXXXVI\non his particular slave p...
# 17  xxxvili\nINTRODUCTION\nqualiﬁed for this if I ...
# 18  INTRODUCTION\nelse's text, rather than letting...
# 19  INTRODUCTION\nxlii\ncommitted what the Garriso...
#
#                                            f_headings
# 0   [F R E D E R I C K D O U G L A S S, P\nE\nN\nG...
# 1   [EC\nREP, REP, ENVIRONMENTAL \nLANGLING, MY BO...
# 2   [G R A D U A L I N I T I AT I O N I N T O, CON...
# 3     [CONTENTS, I, S I O S, S I I O, I\nI, CONTENTS]
# 4         [C O N T E N T S, N I G O, C O N T E N T S]
# 5                                [CONTENTS, CONTENTS]
# 6                  [C O N T E N T S, CONTENTS,  ,   ]
# 7   [EC\nREP, UK\nREP, I N THE FULLEST SENSE O F T...
# 8                        [INTRODUCTION, INTRODUCTION]
# 9             [I N T R O D U C T I O N, INTRODUCTION]
# 10       [INTRODUCTION, I N T R O D U C T I O N\nXXV]
# 11            [INTRODUCTION, I N T R O D U C T I O N]
# 12            [INTRODUCTION, I N T R O D U C T I O N]
# 13                [INTRODUCTION\nX X X, INTRODUCTION]
# 14                       [INTRODUCTION, INTRODUCTION]
# 15      [INTRODUCTION, I N T R O D U C T I O N\nXXXV]
# 16                [INTRODUCTION\nXXXVI, INTRODUCTION]
# 17                       [INTRODUCTION, INTRODUCTION]
# 18                       [INTRODUCTION, INTRODUCTION]
# 19            [INTRODUCTION, I N T R O D U C T I O N]

# %%
df["f_page_nums"] = df["page_text"].map(get_page_numbers)
df
# Out:
#     document     document_value  page page_value           projid  \
# 0          1  UntitledSlice.pdf     1          0  document_parser
# 1          1  UntitledSlice.pdf     2          1  document_parser
# 2          1  UntitledSlice.pdf     3          2  document_parser
# 3          1  UntitledSlice.pdf     4          3  document_parser
# 4          1  UntitledSlice.pdf     5          4  document_parser
# 5          1  UntitledSlice.pdf     6          5  document_parser
# 6          1  UntitledSlice.pdf     7          6  document_parser
# 7          1  UntitledSlice.pdf     8          7  document_parser
# 8          1  UntitledSlice.pdf     9          8  document_parser
# 9          1  UntitledSlice.pdf    10          9  document_parser
# 10         1  UntitledSlice.pdf    11         10  document_parser
# 11         1  UntitledSlice.pdf    12         11  document_parser
# 12         1  UntitledSlice.pdf    13         12  document_parser
# 13         1  UntitledSlice.pdf    14         13  document_parser
# 14         1  UntitledSlice.pdf    15         14  document_parser
# 15         1  UntitledSlice.pdf    16         15  document_parser
# 16         1  UntitledSlice.pdf    17         16  document_parser
# 17         1  UntitledSlice.pdf    18         17  document_parser
# 18         1  UntitledSlice.pdf    19         18  document_parser
# 19         1  UntitledSlice.pdf    20         19  document_parser
#
#                 tstamp      filename  \
# 0  2025-08-29 14:32:53  doc_demux.py
# 1  2025-08-29 14:32:53  doc_demux.py
# 2  2025-08-29 14:32:53  doc_demux.py
# 3  2025-08-29 14:32:53  doc_demux.py
# 4  2025-08-29 14:32:53  doc_demux.py
# 5  2025-08-29 14:32:53  doc_demux.py
# 6  2025-08-29 14:32:53  doc_demux.py
# 7  2025-08-29 14:32:53  doc_demux.py
# 8  2025-08-29 14:32:53  doc_demux.py
# 9  2025-08-29 14:32:53  doc_demux.py
# 10 2025-08-29 14:32:53  doc_demux.py
# 11 2025-08-29 14:32:53  doc_demux.py
# 12 2025-08-29 14:32:53  doc_demux.py
# 13 2025-08-29 14:32:53  doc_demux.py
# 14 2025-08-29 14:32:53  doc_demux.py
# 15 2025-08-29 14:32:53  doc_demux.py
# 16 2025-08-29 14:32:53  doc_demux.py
# 17 2025-08-29 14:32:53  doc_demux.py
# 18 2025-08-29 14:32:53  doc_demux.py
# 19 2025-08-29 14:32:53  doc_demux.py
#
#                                             page_text  \
# 0   The stunning document of intellectual\ntransfo...
# 1   G u a r a n t e e   C a r d   /   保 修 卡\nID No...
# 2   vin\nCHAPTER III.\nTHE AUTHOR'S PARENTAGE.\nAu...
# 3   CHAPTER IX.\nPERSONAL TREATMENT O F T H E AUTH...
# 4   x i l\nNo more Meal brought from the Mill-Meth...
# 5   x i v\nHymns with a Double Meaning,\nAuthor's ...
# 6   xvi\nBecomes a Public Lecturer,\nYouthful Enth...
# 7   G u a r a n t e e   C a r d  /   保 修 卡\nID No....
# 8   INTRODUCTION\nx X\nand a lasting contribution ...
# 9   I N T R O D U C T I O N\nxxii\nFewer still rec...
# 10  INTRODUCTION\nx x i v\nBondage and Freedom is ...
# 11  INTRODUCTION\nxxvi\nterritories and northerner...
# 12  INTRODUCTION\nxxvili\nfor example, in 1833, he...
# 13  INTRODUCTION\nX X X\nriages of many slaveholdi...
# 14  INTRODUCTION\nxxxii\nin my spirit" (98). From ...
# 15  INTRODUCTION\nxxxiv\nhe became an expert caulk...
# 16  INTRODUCTION\nXXXVI\non his particular slave p...
# 17  xxxvili\nINTRODUCTION\nqualiﬁed for this if I ...
# 18  INTRODUCTION\nelse's text, rather than letting...
# 19  INTRODUCTION\nxlii\ncommitted what the Garriso...
#
#                                            f_headings  \
# 0   [F R E D E R I C K D O U G L A S S, P\nE\nN\nG...
# 1   [EC\nREP, REP, ENVIRONMENTAL \nLANGLING, MY BO...
# 2   [G R A D U A L I N I T I AT I O N I N T O, CON...
# 3     [CONTENTS, I, S I O S, S I I O, I\nI, CONTENTS]
# 4         [C O N T E N T S, N I G O, C O N T E N T S]
# 5                                [CONTENTS, CONTENTS]
# 6                  [C O N T E N T S, CONTENTS,  ,   ]
# 7   [EC\nREP, UK\nREP, I N THE FULLEST SENSE O F T...
# 8                        [INTRODUCTION, INTRODUCTION]
# 9             [I N T R O D U C T I O N, INTRODUCTION]
# 10       [INTRODUCTION, I N T R O D U C T I O N\nXXV]
# 11            [INTRODUCTION, I N T R O D U C T I O N]
# 12            [INTRODUCTION, I N T R O D U C T I O N]
# 13                [INTRODUCTION\nX X X, INTRODUCTION]
# 14                       [INTRODUCTION, INTRODUCTION]
# 15      [INTRODUCTION, I N T R O D U C T I O N\nXXXV]
# 16                [INTRODUCTION\nXXXVI, INTRODUCTION]
# 17                       [INTRODUCTION, INTRODUCTION]
# 18                       [INTRODUCTION, INTRODUCTION]
# 19            [INTRODUCTION, I N T R O D U C T I O N]
#
#                                           f_page_nums
# 0   [1818, 1838, 1846, 1, 855, 1845, 17, 00, 23, 0...
# 1   [1, 9144, 28046, 25, 18, 5, 2, 9, 3, 0, 30, 3,...
# 2   [41, 4, 2, 4, 3, 4, 4, 4, 5, 45, 46, 46, 48, 4...
# 3   [9, 7, 98, 9, 9, 9, 9, 1, 1, 0, 2, 0, 2, 3, 1,...
# 4   [4, 4, 1, 4, 5, 1, 4, 6, 4, 1, 4, 7, 1, 4, 7, ...
# 5   [2, 0, 3, 2, 0, 4, 2, 0, 5, 2, 0, 5, 1206, 2, ...
# 6   [2, 6, 4, 2, 6, 5, 2, 6, 6, 2, 6, 6, 267, 4, 2...
# 7   [1, 9144, 28046, 25, 18, 1948, 1817, 1895, 185...
# 8   [4, 125, 1838, 1855, 1881, 1892, 1855, 1881, 1...
# 9       [8, 9, 1855, 1845, 12, 3, 15, 16, 17, 19, 20]
# 10                           [1845, 22, 3, 24, 2, 26]
# 11  [1856, 27, 1850, 1854, 1818, 1818, 1817, 28, 4...
# 12  [1833, 139, 140, 140, 30, 32, 31, 224, 41, 182...
# 13       [47, 41, 53, 64, 96, 61, 62, 33, 54, 99, 35]
# 14  [98, 98, 1827, 12, 233, 1797, 201, 35, 1833, 3...
# 15  [232, 1836, 38, 226, 253, 1838, 236, 38, 39, 1...
# 16  [6, 266, 1845, 4, 42, 1850, 1848, 3, 4, 4, 184...
# 17  [48, 1846, 49, 1847, 277, 52, 1847, 53, 54, 26...
# 18  [291, 266, 58, 1847, 290, 286, 60, 1855, 293, ...
# 19  [1860, 64, 6, 1845, 1855, 1845, 24, 464, 1855,...
