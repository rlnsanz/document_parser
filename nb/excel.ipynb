# %%
import flordb as flor

# %%
df = flor.utils.latest(flor.dataframe("page_text"))
df
# Out:
#      document document_value  page page_value           projid  \
# 0           1  greenbook.pdf     1          0  document_parser
# 1           1  greenbook.pdf     2          1  document_parser
# 2           1  greenbook.pdf     3          2  document_parser
# 3           1  greenbook.pdf     4          3  document_parser
# 4           1  greenbook.pdf     5          4  document_parser
# ..        ...            ...   ...        ...              ...
# 252         1  greenbook.pdf   253        252  document_parser
# 253         1  greenbook.pdf   254        253  document_parser
# 254         1  greenbook.pdf   255        254  document_parser
# 255         1  greenbook.pdf   256        255  document_parser
# 256         1  greenbook.pdf   257        256  document_parser
#
#                  tstamp      filename  \
# 0   2025-10-07 13:30:07  doc_demux.py
# 1   2025-10-07 13:30:07  doc_demux.py
# 2   2025-10-07 13:30:07  doc_demux.py
# 3   2025-10-07 13:30:07  doc_demux.py
# ...

# %%
# export to csv
df.to_csv("greenbook.csv", index=False)
