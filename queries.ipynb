# %%
import flor

df = flor.dataframe("page-source", "page-text")
df.sort_values(by='page', inplace=True)
df.head(20)
# Out:
#      document document_value  page page_value           projid  \
# 0           1  brief_oct2024     1          0  document_parser
# 1           1  brief_oct2024     2          1  document_parser
# 77          1  brief_oct2024     3          2  document_parser
# 88          1  brief_oct2024     4          3  document_parser
# 99          1  brief_oct2024     5          4  document_parser
# 110         1  brief_oct2024     6          5  document_parser
# 121         1  brief_oct2024     7          6  document_parser
# 132         1  brief_oct2024     8          7  document_parser
# 143         1  brief_oct2024     9          8  document_parser
# 154         1  brief_oct2024    10          9  document_parser
# 2           1  brief_oct2024    11         10  document_parser
# 13          1  brief_oct2024    12         11  document_parser
# 24          1  brief_oct2024    13         12  document_parser
# 35          1  brief_oct2024    14         13  document_parser
# ...
