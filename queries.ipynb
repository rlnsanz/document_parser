# %%
import flor

df = flor.dataframe("plain_text", "ocr_text")
df.sort_values(by="page", inplace=True)
df
# Out:
#     document     document_value  page page_value           projid  \
# 0          1  brief_oct2024.pdf     1          0  document_parser
# 1          1  brief_oct2024.pdf     2          1  document_parser
# 77         1  brief_oct2024.pdf     3          2  document_parser
# 88         1  brief_oct2024.pdf     4          3  document_parser
# 99         1  brief_oct2024.pdf     5          4  document_parser
# ..       ...                ...   ...        ...              ...
# 69         1  brief_oct2024.pdf   161        160  document_parser
# 70         1  brief_oct2024.pdf   162        161  document_parser
# 71         1  brief_oct2024.pdf   163        162  document_parser
# 72         1  brief_oct2024.pdf   164        163  document_parser
# 73         1  brief_oct2024.pdf   165        164  document_parser
#
#                 tstamp      filename  \
# 0  2024-10-21 11:51:44  pdf_demux.py
# 1  2024-10-21 11:51:44  pdf_demux.py
# 77 2024-10-21 11:51:44  pdf_demux.py
# ...

# %%
# Get page == 4 row and print the contents of plain_text and ocr_text
page_4 = df[df["page"] == 4]
print("Start of plain_text")
print(page_4["plain_text"].values[0])
print("\nStart of ocr_text")
print(page_4["ocr_text"].values[0])
# Out:
# Start of plain_text
# Case 1:23-cr-00257-TSC   Document 252   Filed 10/02/24   Page 4 of 165
#
#
# Start of ocr_text
# Case 1:23-Cr-00257-TSC Document 252 Filed 10/02/24 Page 4 of 165
# of the presidential election; and 3) a conspiracy against the rights ofmillions of Americans to vote
# and have their votes counted.
# At its core, the defendant's scheme was a private criminal effort. In his capacity as a
# candidate, the defendant used deceit to target every stage of the electoral process, which through
# the Constitution, ECA, and state laws includes the states' notification to the federal government
# of the selection of their representative electors based on the popular vote in the state; the meeting
# of those electors to cast their votes consistent with the popular vote; and Congress' S counting of
# the electors' votes at a certification proceeding. As set forth in detail below, the defendant worked
# with private co-conspirators, including private attorneys
# CC1
# CC2
# CC3
# ...
